# %% [markdown]
# # Team Challenge · Sprint 03-04 - Catálogo de películas
# ---
#
# ## REPARTO DE TAREAS
#
# - **Raul**: Lidera la Parte 1 (Pandas).
# >>>En rama llamada: feature/parte1-pandas
# - **Alejandra**: Lidera la Parte 2 (TMDB API).
# >>>En rama llamada: feature/tmdb-api
# - **Adixon**: Lidera la Parte 3 (Gemini).
# >>>En rama llamada: feature/gemini
# - **Lucas**: Crear el repositorio, configurar .gitignore, escribe el README inicial y Scrum master.
# *A pesar de que cada uno lidere una parte del challenge, acordamos todos intentar hacer todo,  y discutir cual seria la mejor opción de solución*
#
#
#
#
# >El proyecto y el entorno virtual han sido creados en la rama **main**. Aqui podemos encontrar:
# >>>>- data (carpeta con los csv para la parte 1)
# >>>>- .env.prueba (el contenido real de las api keys para google ai y para TMBD os las envio por slack)
# >>>>- .gitignore
# >>>>- requirements.txt
# >>>>- Team_Challenge_sprint03_04.ipynb (donde realizaremos el ejercicio)
# ---
#
#
#
#
#
#
# ## PASOS A SEGUIR
# #### **1.CLONAR EL REPO Y ACTIVAR ENTORNO VIRTUAL**
#
#
# En terminal donde queramos guardar el repo del proyecto:
# ```bash
# git clone https://github.com/vuestro-usuario/tc-sprint03-04.git
# cd tc-sprint03-04
# python -m venv venv
# source venv/bin/activate       # Mac/Linux
# venv\Scripts\activate          # Windows
# pip install -r requirements.txt
# cp .env.example .env           # Editado con claves ya creadas. Los 4 usamos las mismas
# ```
#
#
#
#
# #### **2. WORKFLOW DIARIO**
#
# #### Partir siempre de develop actualizado, de la siguiente manera:
# ```bash
# git checkout develop
# git pull origin develop
# git checkout -b feature/mi-tarea
# ```
#
#
# #### Hacer commits siguiendo esta sintaxis
#
# | Prefijo | Como usarlo | ejemplo |
# |---------|---------|---------|
# |feat:|	Nueva funcionalidad|	feat: función fetch_movie_details con TMDB
# |fix:|	Corrección de bug|	fix: manejar tmdbId nulo en links.csv
# |docs:|	Documentación|	docs: añadir instrucciones de claves en README
# |refactor:|	Refactorización sin cambio funcional|	refactor: extraer groupby a función separada
# |chore:|	Tareas de mantenimiento|	chore: actualizar requirements.txt
#
#
#
# #### Info extra sobre el challenge parte por parte, workflow, reglas, guias...
# [TeamChallenge_Details](./data/guia_tc_sprint03_04.html)
#
# *Archivo .html dentro de la carpet de data*
